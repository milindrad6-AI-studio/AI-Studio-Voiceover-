# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [OmniVoice GitHub Repository](https://github.com/k2-fsa/OmniVoice)
# * 🤗 [OmniVoice on Hugging Face](https://huggingface.co/k2-fsa/OmniVoice)
# * 📄 **License**: Provided under the [Apache License 2.0
# ](https://github.com/k2-fsa/OmniVoice/blob/master/LICENSE)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install OmniVoice
# %cd /content/
# !rm -rf ./omnivoice-colab
# !git clone https://github.com/NeuralFalconYT/omnivoice-colab.git
# %cd ./omnivoice-colab
# !git clone https://github.com/k2-fsa/OmniVoice.git
# !git clone https://github.com/NeuralFalconYT/OmniVoice.git
# !pip install -r colab.txt
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()

# %%
#@title Run Gradio APP
# %cd /content/omnivoice-colab
# !python app.py
# Out:
# /content/omnivoice-colab
# Loading model from k2-fsa/OmniVoice to cuda ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 14:23:55,557 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.24k/2.24k [00:00<00:00, 10.5MB/s]
#
# model.safetensors: downloading bytes:  12% 296M/2.45G [00:01<00:06, 341MB/s, 25.1MB/s  ]
# model.safetensors: downloading bytes:  16% 381M/2.45G [00:01<00:07, 261MB/s, 33.8MB/s  ]
# model.safetensors: downloading bytes:  34% 827M/2.45G [00:03<00:04, 330MB/s, 69.6MB/s  ]
# model.safetensors: downloading bytes:  73% 1.79G/2.45G [00:05<00:01, 420MB/s,  130MB/s  ]
# model.safetensors: downloading bytes:  94% 2.30G/2.45G [00:08<00:00, 226MB/s,  145MB/s  ]
# model.safetensors: reconstructing file:  57% 1.41G/2.45G [00:10<00:07, 139MB/s, 57.9MB/s  ]
# model.safetensors: downloading bytes: 100% 2.32G/2.32G [00:15<00:00, 149MB/s,  147MB/s  ]
# model.safetensors: reconstructing file: 100% 2.45G/2.45G [00:15<00:00, 157MB/s,  142MB/s  ]
# Loading weights: 100% 313/313 [00:00<00:00, 363.48it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Downloading bytes:   0% 1.57k/806M [00:00<15:48:43, 14.2kB/s]
#
# Fetching 13 files:   8% 1/13 [00:00<00:01,  8.99it/s]
# Reconstructing (incomplete total...):   0% 1.57k/806M [00:00<15:45:13, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 11.0k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 11.0k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 11.2k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 16.4k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 18.9k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 20.4k/817M [00:00<15:58:37, 14.2kB/s]
# Reconstructing (incomplete total...):   0% 29.6k/817M [00:00<15:58:37, 14.2kB/s]
# Downloading bytes:   0% 33.8k/817M [00:00<1:17:13, 176kB/s]
#
# Fetching 13 files:  77% 10/13 [00:00<00:00, 51.38it/s]
# Downloading bytes:   0% 2.23M/817M [00:00<02:53, 4.68MB/s]
# Downloading bytes:   8% 64.6M/817M [00:00<00:05, 133MB/s, 77.0MB/s  ]
# Downloading bytes:  26% 212M/817M [00:01<00:02, 300MB/s,  279MB/s  ]
# Downloading bytes:  80% 655M/817M [00:02<00:00, 209MB/s,  224MB/s  ]
# Reconstructing (incomplete total...):  38% 309M/817M [00:03<00:04, 109MB/s, 28.3MB/s  ]
# Reconstructing (incomplete total...):  40% 327M/817M [00:03<00:04, 113MB/s,  109MB/s  ]
# Reconstructing (incomplete total...):  43% 350M/817M [00:03<00:03, 121MB/s,  113MB/s  ]
# Reconstructing (incomplete total...):  54% 437M/817M [00:03<00:02, 158MB/s,  121MB/s  ]
# Reconstructing (incomplete total...):  56% 459M/817M [00:04<00:02, 163MB/s,  158MB/s  ]
# Reconstructing (incomplete total...):  62% 506M/817M [00:04<00:01, 179MB/s,  163MB/s  ]
# Reconstructing (incomplete total...):  69% 560M/817M [00:04<00:01, 200MB/s,  179MB/s  ]
# Reconstructing (incomplete total...):  75% 617M/817M [00:04<00:00, 221MB/s,  200MB/s  ]
# Reconstructing (incomplete total...):  82% 674M/817M [00:04<00:00, 237MB/s,  221MB/s  ]
# Fetching 13 files: 100% 13/13 [00:07<00:00,  1.84it/s]
# Download complete: 100% 663M/663M [00:07<00:00, 209MB/s,  209MB/s  ]
# Download complete: 100% 663M/663M [00:08<00:00, 76.2MB/s,  209MB/s  ]
# Reconstruction complete: 100% 817M/817M [00:08<00:00, 94.0MB/s, 65.8MB/s  ]
# Loading weights: 100% 527/527 [00:00<00:00, 1638.57it/s]
# Model loaded successfully!
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://eafe3397b8c23c4ce1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)

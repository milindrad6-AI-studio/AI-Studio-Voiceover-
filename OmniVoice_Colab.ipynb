# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [OmniVoice GitHub Repository](https://github.com/k2-fsa/OmniVoice)
# * 🤗 [OmniVoice on Hugging Face](https://huggingface.co/k2-fsa/OmniVoice)
# * 📄 **License**: Provided under the [Apache License 2.0
# ](https://github.com/k2-fsa/OmniVoice/blob/master/LICENSE)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install OmniVoice
# %cd /content/
# !rm -rf ./omnivoice-colab
# !git clone https://github.com/NeuralFalconYT/omnivoice-colab.git
# %cd ./omnivoice-colab
# !git clone https://github.com/k2-fsa/OmniVoice.git
# !git clone https://github.com/NeuralFalconYT/OmniVoice.git
# !pip install -r colab.txt
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()

# %%
#@title Run Gradio APP
# %cd /content/omnivoice-colab
# !python app.py
# Out:
# /content/omnivoice-colab
# Loading model from k2-fsa/OmniVoice to cuda ...
# config.json: 100% 2.24k/2.24k [00:00<00:00, 4.33MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-08-21 13:34:14,031 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# model.safetensors: downloading bytes:   9% 232M/2.45G [00:01<00:06, 338MB/s, 18.3MB/s  ]
# model.safetensors: downloading bytes:  71% 1.75G/2.45G [00:06<00:03, 215MB/s,  117MB/s  ]
# model.safetensors: downloading bytes:  81% 1.98G/2.45G [00:08<00:03, 124MB/s,  118MB/s  ]
# model.safetensors: downloading bytes:  84% 2.06G/2.45G [00:09<00:02, 159MB/s,  120MB/s  ]
# model.safetensors: downloading bytes:  89% 2.18G/2.45G [00:09<00:01, 205MB/s,  124MB/s  ]
# model.safetensors: downloading bytes:  95% 2.32G/2.45G [00:10<00:00, 178MB/s,  129MB/s  ]
# model.safetensors: reconstructing file:  74% 1.81G/2.45G [00:10<00:03, 201MB/s,  116MB/s  ]
# model.safetensors: downloading bytes: 100% 2.32G/2.32G [00:17<00:00, 133MB/s,  129MB/s  ]
# model.safetensors: reconstructing file: 100% 2.45G/2.45G [00:17<00:00, 140MB/s,  122MB/s  ]
# Loading weights: 100% 313/313 [00:01<00:00, 296.09it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 1.52k/806M [00:00<17:43:51, 12.6kB/s]
# Downloading bytes:   0% 10.7k/806M [00:00<2:39:04, 84.4kB/s]
#
# Fetching 13 files:  15% 2/13 [00:00<00:00, 15.11it/s]
# Reconstructing (incomplete total...):   0% 10.7k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 10.7k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 12.3k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 17.4k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 26.9k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 27.1k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 29.6k/817M [00:00<2:40:44, 84.7kB/s]
# Reconstructing (incomplete total...):   0% 33.8k/817M [00:00<2:40:44, 84.7kB/s]
# Downloading bytes:   1% 12.1M/817M [00:00<00:27, 28.8MB/s, 1.67MB/s  ]
# Reconstructing (incomplete total...):   1% 11.6M/817M [00:00<00:34, 23.7MB/s,  136kB/s  ]
#
# Downloading bytes:  23% 192M/817M [00:01<00:03, 171MB/s,  168MB/s  ]
# Downloading bytes:  72% 590M/817M [00:03<00:01, 174MB/s,  194MB/s  ]
# Downloading bytes:  78% 640M/817M [00:03<00:00, 205MB/s,  180MB/s  ]
# Downloading bytes:  81% 663M/817M [00:04<00:00, 168MB/s,  205MB/s  ]
# Reconstructing (incomplete total...):  26% 213M/817M [00:04<00:07, 78.7MB/s, 48.0MB/s  ]
# Reconstructing (incomplete total...):  38% 309M/817M [00:04<00:03, 141MB/s, 78.7MB/s  ]
# Reconstructing (incomplete total...):  45% 371M/817M [00:04<00:02, 156MB/s,  141MB/s  ]
# Reconstructing (incomplete total...):  54% 438M/817M [00:04<00:02, 188MB/s,  156MB/s  ]
# Reconstructing (incomplete total...):  63% 515M/817M [00:05<00:01, 207MB/s,  188MB/s  ]
# Reconstructing (incomplete total...):  69% 563M/817M [00:05<00:01, 213MB/s,  207MB/s  ]
# Reconstructing (incomplete total...):  76% 619M/817M [00:05<00:00, 227MB/s,  213MB/s  ]
# Reconstructing (incomplete total...):  83% 676M/817M [00:05<00:00, 213MB/s,  227MB/s  ]
# Fetching 13 files: 100% 13/13 [00:08<00:00,  1.61it/s]
# Download complete: 100% 663M/663M [00:08<00:00, 168MB/s,  168MB/s  ]
# Download complete: 100% 663M/663M [00:09<00:00, 69.3MB/s,  168MB/s  ]
# Reconstruction complete: 100% 817M/817M [00:09<00:00, 85.4MB/s, 97.8MB/s  ]
# Loading weights: 100% 527/527 [00:00<00:00, 1459.29it/s]
# Model loaded successfully!
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f608fe5891c4dbaabe.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-08-21 13:38:59,433 omnivoice.models.omnivoice DEBUG: Item 0 — text: एक
# झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।” [sigh]
#  [confirmation-en] | ref_text: एक झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।”. | instruct: None | lang: None | target_tokens: 221
# 2026-08-21 13:39:47,185 omnivoice.models.omnivoice DEBUG: Item 0 — text: एक
# झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।” [sigh]
#  [confirmation-en] | ref_text: एक झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।”. | instruct: None | lang: hi | target_tokens: 221
# 2026-08-21 13:40:36,378 omnivoice.models.omnivoice DEBUG: Item 0 — text: एक
# झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।” [sigh]
#  [confirmation-en] [confirmation-en] | ref_text: एक झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।”. | instruct: None | lang: hi | target_tokens: 230
# 2026-08-21 13:40:50,548 omnivoice.models.omnivoice DEBUG: Item 0 — text: एक
# झोंपड़े के द्वार पर बाप और बेटा दोनों एक बुझे हुए अलाव के सामने चुपचाप बैठे हुए थे और अंदर बेटे की जवान बीवी बुधिया प्रसव-वेदना में पछाड़ खा रही थी। रह-रहकर उसके मुँह से ऐसी दिल हिला देने वाली आवाज़ निकलती थी, कि दोनों कलेजा थाम लेते थे। जाड़ों की रात थी, प्रकृति सन्नाटे में डूबी हुई, सारा गाँव अंधकार में लय हो गया था। घीसू ने कहा—“मालूम होता है, बचेगी नहीं। सारा दिन दौड़ते हो गया, जा देख तो आ।” [sigh]
#  [confirmation-en] [confirmation-en] | ref_text: बहुत weird feeling होती है न, जब आप जानते हो कि उस इंसान के साथ आपका एक connection है, पर फिर भी वो आपका नहीं हो सकता. | instruct: None | lang: hi | target_tokens: 726
